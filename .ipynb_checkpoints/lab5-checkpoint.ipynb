# %% [markdown]
# <a href="https://colab.research.google.com/github/marisaaaai/lab5/blob/main/lab5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Laboratorio 5.
# ## Análisis de Sentimientos
#
# ---
# Participantes:
#
#
# *   María Isabel Montoya Valladares 19169
# *   Luis Pedro García Salazar 19344
# * María José Morales Reichenbach 19145
#
# ### Carga de librerias

# %%
import pandas as pd #libreria de visualizacion de texto
import numpy as np #libreria de operaciones matematicas
import string #analisis de texto
import re #operaciones de texto
import zipfile #unzip files
import nltk #libreria para analisis
from nltk.corpus import stopwords #eliminacion de stopwrod
from wordcloud import WordCloud #graficas
import matplotlib.pyplot as plt #graficas
from nltk.sentiment.vader import SentimentIntensityAnalyzer #polaridad del texto

# %% [markdown]
# ### visualizacion de datos

# %%
file_name = 'GrammarandProductReviews.csv.zip'
with zipfile.ZipFile(file_name, 'r') as file:
    file.extractall()
datos=pd.read_csv('GrammarandProductReviews.csv')
datos.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 3  kylovesensualitypleasuregel/b00u2whx8s,0679819...
# 4  kylovesensualitypleasuregel/b00u2whx8s,0679819...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
# 2                            Lundberg             574764
# 3                                 K-Y        67981934427
# 4                                 K-Y        67981934427
#
#                                          name  ...   reviews.id  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...          NaN
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 3            K-Y Love Sensuality Pleasure Gel  ...  113026909.0
# 4            K-Y Love Sensuality Pleasure Gel  ...  171267657.0
#
#   reviews.numHelpful reviews.rating  \
# 0                0.0              5
# 1                NaN              5
# 2                NaN              5
# 3                NaN              1
# 4                NaN              1
#
#                                   reviews.sourceURLs  \
# 0  https://redsky.target.com/groot-domain-api/v1/...
# 1   https://www.walmart.com/reviews/product/29775278
# 2   https://www.walmart.com/reviews/product/29775278
# 3   https://www.walmart.com/reviews/product/43383370
# 4   https://www.walmart.com/reviews/product/43383370
#
#                                         reviews.text  reviews.title  \
# 0  i love this album. it's very good. more to the...   Just Awesome
# 1  Good flavor. This review was collected as part...           Good
# 2                                       Good flavor.           Good
# 3  I read through the reviews on here before look...   Disappointed
# 4  My husband bought this gel for us. The gel cau...     Irritation
#
#    reviews.userCity  reviews.userProvince reviews.username          upc
# 0       Los Angeles                   NaN           Joshua  6.02537E+11
# 1               NaN                   NaN        Dorothy W  73416000391
# 2               NaN                   NaN        Dorothy W  73416000391
# 3               NaN                   NaN          Rebecca  67981934427
# 4               NaN                   NaN        Walker557  67981934427
#
# [5 rows x 25 columns]

# %% [markdown]
# ### Limpieza y Procesamiento de Datos
# Para la limpieza de los datos se haran cambios de todas las letras a minusculas, se eliminaran los signos de puntuación, emojis, URLs y stopwords. Finalmente también cabe mencionar que se debe de eliminar los reviews en los que tengan valores nulos en la columna review.text
#
# #### Eliminacion de NAN's

# %%
datos = datos.dropna(subset=['reviews.text'])

# %% [markdown]
# #### De Mayuscula a minuscula

# %%
datos['reviews.text'] = datos['reviews.text'].apply(lambda line: line.lower())
datos.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 3  kylovesensualitypleasuregel/b00u2whx8s,0679819...
# 4  kylovesensualitypleasuregel/b00u2whx8s,0679819...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
# 2                            Lundberg             574764
# 3                                 K-Y        67981934427
# 4                                 K-Y        67981934427
#
#                                          name  ...   reviews.id  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...          NaN
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 3            K-Y Love Sensuality Pleasure Gel  ...  113026909.0
# 4            K-Y Love Sensuality Pleasure Gel  ...  171267657.0
#
#   reviews.numHelpful reviews.rating  \
# 0                0.0              5
# 1                NaN              5
# 2                NaN              5
# 3                NaN              1
# 4                NaN              1
#
#                                   reviews.sourceURLs  \
# 0  https://redsky.target.com/groot-domain-api/v1/...
# 1   https://www.walmart.com/reviews/product/29775278
# 2   https://www.walmart.com/reviews/product/29775278
# 3   https://www.walmart.com/reviews/product/43383370
# 4   https://www.walmart.com/reviews/product/43383370
#
#                                         reviews.text  reviews.title  \
# 0  i love this album. it's very good. more to the...   Just Awesome
# 1  good flavor. this review was collected as part...           Good
# 2                                       good flavor.           Good
# 3  i read through the reviews on here before look...   Disappointed
# 4  my husband bought this gel for us. the gel cau...     Irritation
#
#    reviews.userCity  reviews.userProvince reviews.username          upc
# 0       Los Angeles                   NaN           Joshua  6.02537E+11
# 1               NaN                   NaN        Dorothy W  73416000391
# 2               NaN                   NaN        Dorothy W  73416000391
# 3               NaN                   NaN          Rebecca  67981934427
# 4               NaN                   NaN        Walker557  67981934427
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Eliminación de caracteres especiales

# %%
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text
datos['reviews.text'] = datos['reviews.text'].apply(remove_punctuations)
datos.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 3  kylovesensualitypleasuregel/b00u2whx8s,0679819...
# 4  kylovesensualitypleasuregel/b00u2whx8s,0679819...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
# 2                            Lundberg             574764
# 3                                 K-Y        67981934427
# 4                                 K-Y        67981934427
#
#                                          name  ...   reviews.id  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...          NaN
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 3            K-Y Love Sensuality Pleasure Gel  ...  113026909.0
# 4            K-Y Love Sensuality Pleasure Gel  ...  171267657.0
#
#   reviews.numHelpful reviews.rating  \
# 0                0.0              5
# 1                NaN              5
# 2                NaN              5
# 3                NaN              1
# 4                NaN              1
#
#                                   reviews.sourceURLs  \
# 0  https://redsky.target.com/groot-domain-api/v1/...
# 1   https://www.walmart.com/reviews/product/29775278
# 2   https://www.walmart.com/reviews/product/29775278
# 3   https://www.walmart.com/reviews/product/43383370
# 4   https://www.walmart.com/reviews/product/43383370
#
#                                         reviews.text  reviews.title  \
# 0  i love this album its very good more to the hi...   Just Awesome
# 1  good flavor this review was collected as part ...           Good
# 2                                        good flavor           Good
# 3  i read through the reviews on here before look...   Disappointed
# 4  my husband bought this gel for us the gel caus...     Irritation
#
#    reviews.userCity  reviews.userProvince reviews.username          upc
# 0       Los Angeles                   NaN           Joshua  6.02537E+11
# 1               NaN                   NaN        Dorothy W  73416000391
# 2               NaN                   NaN        Dorothy W  73416000391
# 3               NaN                   NaN          Rebecca  67981934427
# 4               NaN                   NaN        Walker557  67981934427
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Eliminacion de URLs

# %%
datos['reviews.text'] = datos['reviews.text'].apply(lambda x: re.split('https:\/\/.*', str(x))[0])
datos.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 3  kylovesensualitypleasuregel/b00u2whx8s,0679819...
# 4  kylovesensualitypleasuregel/b00u2whx8s,0679819...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
# 2                            Lundberg             574764
# 3                                 K-Y        67981934427
# 4                                 K-Y        67981934427
#
#                                          name  ...   reviews.id  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...          NaN
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  ...  100209113.0
# 3            K-Y Love Sensuality Pleasure Gel  ...  113026909.0
# 4            K-Y Love Sensuality Pleasure Gel  ...  171267657.0
#
#   reviews.numHelpful reviews.rating  \
# 0                0.0              5
# 1                NaN              5
# 2                NaN              5
# 3                NaN              1
# 4                NaN              1
#
#                                   reviews.sourceURLs  \
# 0  https://redsky.target.com/groot-domain-api/v1/...
# 1   https://www.walmart.com/reviews/product/29775278
# 2   https://www.walmart.com/reviews/product/29775278
# 3   https://www.walmart.com/reviews/product/43383370
# 4   https://www.walmart.com/reviews/product/43383370
#
#                                         reviews.text  reviews.title  \
# 0  i love this album its very good more to the hi...   Just Awesome
# 1  good flavor this review was collected as part ...           Good
# 2                                        good flavor           Good
# 3  i read through the reviews on here before look...   Disappointed
# 4  my husband bought this gel for us the gel caus...     Irritation
#
#    reviews.userCity  reviews.userProvince reviews.username          upc
# 0       Los Angeles                   NaN           Joshua  6.02537E+11
# 1               NaN                   NaN        Dorothy W  73416000391
# 2               NaN                   NaN        Dorothy W  73416000391
# 3               NaN                   NaN          Rebecca  67981934427
# 4               NaN                   NaN        Walker557  67981934427
#
# [5 rows x 25 columns]

# %% [markdown]
# #### Quitar emojis

# %%
datos.astype(str).apply(lambda x: x.str.encode('ascii', 'ignore').str.decode('ascii'))
datos.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 3  kylovesensualitypleasuregel/b00u2whx8s,0679819...
# 4  kylovesensualitypleasuregel/b00u2whx8s,0679819...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
# 2                            Lundberg             574764
# 3                                 K-Y        67981934427
# 4                                 K-Y        67981934427
#
#                                          name  ... reviews.numHelpful  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...                0.0
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...                NaN
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  ...                NaN
# 3            K-Y Love Sensuality Pleasure Gel  ...                NaN
# 4            K-Y Love Sensuality Pleasure Gel  ...                NaN
#
#   reviews.rating                                 reviews.sourceURLs  \
# 0              5  https://redsky.target.com/groot-domain-api/v1/...
# 1              5   https://www.walmart.com/reviews/product/29775278
# 2              5   https://www.walmart.com/reviews/product/29775278
# 3              1   https://www.walmart.com/reviews/product/43383370
# 4              1   https://www.walmart.com/reviews/product/43383370
#
#                                         reviews.text reviews.title  \
# 0  i love this album its very good more to the hi...  Just Awesome
# 1  good flavor this review was collected as part ...          Good
# 2                                        good flavor          Good
# 3  i read through the reviews on here before look...  Disappointed
# 4  my husband bought this gel for us the gel caus...    Irritation
#
#    reviews.userCity  reviews.userProvince  reviews.username          upc  \
# 0       Los Angeles                   NaN            Joshua  6.02537E+11
# 1               NaN                   NaN         Dorothy W  73416000391
# 2               NaN                   NaN         Dorothy W  73416000391
# 3               NaN                   NaN           Rebecca  67981934427
# 4               NaN                   NaN         Walker557  67981934427
#
#   review.class
# 0          Pos
# 1          Pos
# 2          Pos
# 3          Neg
# 4          Neg
#
# [5 rows x 26 columns]

# %% [markdown]
# #### Eliminacion de Stopwords

# %%
stop = stopwords.words('english')

datos['reviewsnostop.text'] = datos['reviews.text'].str.lower().str.split() 

datos['reviewsnostop.text'] = datos['reviewsnostop.text'].apply(lambda x: [item for item in x if item not in stop])
datos.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 3  kylovesensualitypleasuregel/b00u2whx8s,0679819...
# 4  kylovesensualitypleasuregel/b00u2whx8s,0679819...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
# 2                            Lundberg             574764
# 3                                 K-Y        67981934427
# 4                                 K-Y        67981934427
#
#                                          name  ... reviews.rating  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...              5
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...              5
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  ...              5
# 3            K-Y Love Sensuality Pleasure Gel  ...              1
# 4            K-Y Love Sensuality Pleasure Gel  ...              1
#
#                                   reviews.sourceURLs  \
# 0  https://redsky.target.com/groot-domain-api/v1/...
# 1   https://www.walmart.com/reviews/product/29775278
# 2   https://www.walmart.com/reviews/product/29775278
# 3   https://www.walmart.com/reviews/product/43383370
# 4   https://www.walmart.com/reviews/product/43383370
#
#                                         reviews.text reviews.title  \
# 0  i love this album its very good more to the hi...  Just Awesome
# 1  good flavor this review was collected as part ...          Good
# 2                                        good flavor          Good
# 3  i read through the reviews on here before look...  Disappointed
# 4  my husband bought this gel for us the gel caus...    Irritation
#
#   reviews.userCity  reviews.userProvince  reviews.username          upc  \
# 0      Los Angeles                   NaN            Joshua  6.02537E+11
# 1              NaN                   NaN         Dorothy W  73416000391
# 2              NaN                   NaN         Dorothy W  73416000391
# 3              NaN                   NaN           Rebecca  67981934427
# 4              NaN                   NaN         Walker557  67981934427
#
#   review.class                                 reviewsnostop.text
# 0          Pos  [love, album, good, hip, hop, side, current, p...
# 1          Pos  [good, flavor, review, collected, part, promot...
# 2          Pos                                     [good, flavor]
# 3          Neg  [read, reviews, looking, buying, one, couples,...
# 4          Neg  [husband, bought, gel, us, gel, caused, irrita...
#
# [5 rows x 27 columns]

# %%
datos['reviews.text'] = [' '.join(map(str, l)) for l in datos['reviewsnostop.text']]

datos.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 3  kylovesensualitypleasuregel/b00u2whx8s,0679819...
# 4  kylovesensualitypleasuregel/b00u2whx8s,0679819...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
# 2                            Lundberg             574764
# 3                                 K-Y        67981934427
# 4                                 K-Y        67981934427
#
#                                          name  ... reviews.rating  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...              5
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...              5
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  ...              5
# 3            K-Y Love Sensuality Pleasure Gel  ...              1
# 4            K-Y Love Sensuality Pleasure Gel  ...              1
#
#                                   reviews.sourceURLs  \
# 0  https://redsky.target.com/groot-domain-api/v1/...
# 1   https://www.walmart.com/reviews/product/29775278
# 2   https://www.walmart.com/reviews/product/29775278
# 3   https://www.walmart.com/reviews/product/43383370
# 4   https://www.walmart.com/reviews/product/43383370
#
#                                         reviews.text reviews.title  \
# 0  love album good hip hop side current pop sound...  Just Awesome
# 1        good flavor review collected part promotion          Good
# 2                                        good flavor          Good
# 3  read reviews looking buying one couples lubric...  Disappointed
# 4  husband bought gel us gel caused irritation fe...    Irritation
#
#   reviews.userCity  reviews.userProvince  reviews.username          upc  \
# 0      Los Angeles                   NaN            Joshua  6.02537E+11
# 1              NaN                   NaN         Dorothy W  73416000391
# 2              NaN                   NaN         Dorothy W  73416000391
# 3              NaN                   NaN           Rebecca  67981934427
# 4              NaN                   NaN         Walker557  67981934427
#
#   review.class                                 reviewsnostop.text
# 0          Pos  [love, album, good, hip, hop, side, current, p...
# 1          Pos  [good, flavor, review, collected, part, promot...
# 2          Pos                                     [good, flavor]
# 3          Neg  [read, reviews, looking, buying, one, couples,...
# 4          Neg  [husband, bought, gel, us, gel, caused, irrita...
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Análisis Exploratorio

# %% [markdown]
# #### Palabras mas frecuentes

# %% [markdown]
# ##### Palabras mas frecuentes por rating 1

# %%
def most_used_words(data):
    wordcloud = WordCloud(
        background_color='white',
        stopwords=stop,
        max_words=20,
        max_font_size=40, 
        scale=3,
        random_state=1).generate(str(data))

    fig = plt.figure(1, figsize=(15, 15))
    plt.axis('off')
    plt.imshow(wordcloud)
    plt.show()
    
r1 = datos.loc[datos['reviews.rating']==1, ['reviews.text']]
most_used_words(r1)

# %% [markdown]
# ##### Palabras mas frecuentes por rating 2

# %%
r2 = datos.loc[datos['reviews.rating']==2, ['reviews.text']]
most_used_words(r2)

# %% [markdown]
# ##### Palabras mas frecuentes por rating 3

# %%
r3 = datos.loc[datos['reviews.rating']==3, ['reviews.text']]
most_used_words(r3)

# %% [markdown]
# ##### Palabras mas frecuentes por rating 4

# %%
r4 = datos.loc[datos['reviews.rating']==4, ['reviews.text']]
most_used_words(r4)

# %% [markdown]
# ##### Palabras mas frecuentes por rating 5

# %%
r5 = datos.loc[datos['reviews.rating']==5, ['reviews.text']]
most_used_words(r5)

# %% [markdown]
# #### Histograma de cantidad de reviews por rating

# %%
import seaborn as sns

sns.countplot(datos['reviews.rating'])
# Out:
# /home/luispedro/.local/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='reviews.rating', ylabel='count'>

# %% [markdown]
# #### Interpretación de las palabras más frecuentes
# Claramente en las reviews que tienen un rating alto, podemos encontrar palabras como good, great, love, loved... etc. Lo cual nos indica que usan estos adjetivos para describir el producto con el que están satisfechos. En los malos reviews sorprendentemente nos encontramos con palabras como husband y boyfriend (?), lo cual nos puede indicar que tal vez fueron regalos de los cuales no se fijaron en la calidad del producto, también en los ratings bajos encontramos más palabras en un sentido negativo y en tiempo pasado, en comparación con los buenos ratings.

# %% [markdown]
# #### Determinación de palabras positivas o negativas
# Para poder hacer esto se hara tomando en cuenta el rating que tuvieron, siendo 1 y 2 negativas, 3 neutral y 4 y 5 positivas.

# %%
def classi(rating):
    if rating < 3:
        return 'Neg'
    elif rating == 3:
        return 'Neutral'
    else:
        return 'Pos'
datos['review.class'] = datos['reviews.rating'].apply(lambda rate: classi(rate))
pos = {} #dic con counters
neg = {}
    
for review, classif in zip(datos['reviews.text'], datos['review.class']):
    text = review.split(' ')
    for word in text:
        if word not in stop and word != '':
            if classif == 'Pos':
                counter = pos.get(word)
                if counter:
                    pos[word] = counter + 1
                else:
                    pos[word] = 1
            elif classif == 'Neg':
                counter = neg.get(word)
                if counter:
                    neg[word] = counter + 1
                else:
                    neg[word] = 1

# %% [markdown]
# ##### Positivas

# %%
pos
# Out:
# {'love': 15936,
#  'album': 190,
#  'good': 10152,
#  'hip': 7,
#  'hop': 4,
#  'side': 329,
#  'current': 71,
#  'pop': 277,
#  'sound': 638,
#  'hype': 30,
#  'listen': 95,
#  'everyday': 697,
#  'gym': 77,
#  'give': 935,
#  '5star': 10,
#  'rating': 78,
#  'way': 2540,
#  'metaphors': 1,
#  'crazy': 193,
#  'flavor': 325,
#  'review': 17133,
#  'collected': 16243,
#  'part': 16965,
#  'promotion': 16247,
#  'noticed': 1180,
#  'product': 15977,
#  'clearance': 10,
#  'store': 875,
#  'shop': 66,
#  'frequently': 80,
#  'decided': 382,
#  'try': 2254,
#  'husband': 757,
#  'went': 739,
#  'back': 1957,
#  'bought': 2392,
#  'every': 2407,
#  'box': 435,
#  'left': 1200,
#  'like': 8612,
#  'others': 616,
#  'mentioned': 50,
#  'sure': 1183,
#  'supposed': 103,
#  'lubricant': 3,
#  'purpose': 88,
#  'much': 4163,
#  'better': 3081,
#  'regular': 586,
#  'ky': 1,
#  'jelly': 10,
#  'tends': 78,
#  'dry': 2958,
#  'disappear': 60,
#  'us': 541,
#  'stays': 287,
#  'awhile': 100,
#  'makes': 2627,
#  'pleasurable': 3,
#  'experience': 308,
#  'drawback': 49,
#  'find': 1719,
#  'bit': 1258,
#  'sticky': 352,
#  'applying': 289,
#  'hands': 616,
#  'youre': 420,
#  'hand': 535,
#  'agree': 76,
#  'little': 3337,
#  'goes': 1021,
#  'long': 2274,
#  'personally': 139,
#  'careful': 67,
#  'products': 3786,
#  'due': 341,
#  'skin': 8684,
#  'irritation': 69,
#  'surprisingly': 74,
#  'actually': 936,
#  'seems': 611,
#  'help': 959,
#  'receive': 192,
#  'sample': 1014,
#  'never': 2111,
#  'used': 4828,
#  'couple': 645,
#  'times': 1263,
#  'since': 1909,
#  'recived': 10,
#  'free': 2497,
#  'experiance': 1,
#  'feel': 3604,
#  'warm': 101,
#  'pretty': 1206,
#  'sensation': 34,
#  'recomend': 67,
#  'bad': 694,
#  'loved': 3399,
#  'great': 19353,
#  'feeling': 1596,
#  'really': 7301,
#  'enjoyed': 2219,
#  'using': 6150,
#  '20': 267,
#  'years': 2513,
#  'marriage': 11,
#  'things': 875,
#  'tend': 191,
#  'get': 4099,
#  'tired': 119,
#  'boring': 49,
#  'thing': 1032,
#  'needed': 592,
#  'shake': 16,
#  'packaging': 284,
#  'pump': 230,
#  'dispenser': 72,
#  'awesome': 1807,
#  'disappoint': 151,
#  'provides': 138,
#  'slight': 137,
#  'warming': 25,
#  'use': 13738,
#  'become': 228,
#  'tacky': 23,
#  'anyway': 101,
#  'excellent': 1316,
#  'choice': 201,
#  'intimate': 1,
#  'received': 2617,
#  'opinions': 820,
#  '100': 189,
#  'couples': 8,
#  'lot': 1771,
#  'lubricantsit': 1,
#  'easy': 5460,
#  'clean': 7281,
#  'usei': 13,
#  'absolutely': 1173,
#  'purchasing': 345,
#  'future': 399,
#  'reviewopinions': 1,
#  'exceptional': 34,
#  'smooth': 1781,
#  'slimy': 13,
#  'partners': 1,
#  'share': 99,
#  'least': 402,
#  'lifetime': 16,
#  'first': 3787,
#  'time': 4814,
#  'boyfriend': 68,
#  'didnt': 1784,
#  'felt': 1199,
#  'entire': 620,
#  'exactly': 282,
#  'says': 308,
#  'works': 2646,
#  'well': 5363,
#  'yes': 287,
#  'scent': 2830,
#  'best': 4147,
#  'lemon': 367,
#  'frosting': 6,
#  'wont': 472,
#  'able': 889,
#  'enough': 1194,
#  'lotion': 712,
#  'also': 3879,
#  'almost': 863,
#  'natural': 607,
#  'none': 165,
#  'yucky': 26,
#  'ingredients': 140,
#  'major': 94,
#  'brands': 588,
#  'mineral': 30,
#  'oil': 596,
#  'petroleum': 12,
#  'etc': 417,
#  'completely': 368,
#  'know': 1832,
#  'sometimes': 401,
#  'opt': 11,
#  'organic': 58,
#  'choices': 42,
#  'popular': 48,
#  'nastier': 1,
#  'jr': 8,
#  'watkins': 2,
#  'delivers': 86,
#  'softens': 28,
#  'body': 336,
#  'leaves': 1312,
#  'ungreasy': 1,
#  'smells': 2079,
#  'perfect': 1609,
#  'even': 3458,
#  'fiance': 10,
#  'likes': 180,
#  'uses': 380,
#  'hes': 98,
#  'antilotion': 1,
#  'regards': 15,
#  'price': 2343,
#  'right': 1350,
#  'tooget': 1,
#  'handcreamlemoncream': 1,
#  'refreshing': 213,
#  'fragrance': 472,
#  'wish': 829,
#  'would': 6148,
#  'last': 1278,
#  'day': 3322,
#  'soothing': 61,
#  'compliments': 233,
#  'especially': 1377,
#  'daughters': 161,
#  'granddaughters': 34,
#  'want': 1185,
#  'one': 7754,
#  'favorite': 1374,
#  'creams': 188,
#  'still': 2133,
#  'vanilla': 21,
#  'cream': 1378,
#  'cookie': 31,
#  'kids': 4224,
#  'smile': 56,
#  'put': 1584,
#  'nice': 2775,
#  'desk': 164,
#  'work': 2359,
#  'someone': 297,
#  'stole': 16,
#  'two': 1423,
#  'days': 1508,
#  'broke': 150,
#  'heart': 138,
#  'thick': 738,
#  'feet': 138,
#  'clearing': 13,
#  'complexion': 120,
#  '2': 1502,
#  'weeks': 1181,
#  'keep': 2575,
#  'super': 1232,
#  'ashy': 13,
#  'dont': 3257,
#  'follow': 258,
#  'moisturiser': 27,
#  'soon': 334,
#  'im': 3165,
#  'done': 1312,
#  'doesnt': 1750,
#  'oily': 1490,
#  'radiant': 101,
#  'foundation': 215,
#  'concealer': 114,
#  'make': 2617,
#  'look': 2415,
#  'hydrated': 480,
#  'face': 2783,
#  'fresh': 2418,
#  '3': 1286,
#  'acne': 208,
#  'cleared': 53,
#  'deff': 14,
#  'soap': 378,
#  'considered': 27,
#  'walmarts': 11,
#  'kept': 488,
#  'secret': 168,
#  'disappointed': 411,
#  'stopped': 147,
#  'carrying': 66,
#  'location': 21,
#  'delighted': 27,
#  'see': 2797,
#  'could': 1756,
#  'online': 260,
#  'ended': 133,
#  'blessing': 16,
#  'go': 2417,
#  'walmart': 281,
#  'often': 416,
#  'saving': 71,
#  'money': 681,
#  'sorry': 43,
#  'delivery': 82,
#  'prompt': 6,
#  'stockpiled': 3,
#  'house': 2021,
#  'johnsons': 7,
#  'need': 1751,
#  'say': 1502,
#  'ok': 314,
#  'baby': 450,
#  'lets': 102,
#  'chase': 6,
#  '1': 1136,
#  'come': 1166,
#  'hard': 1082,
#  'loves': 1095,
#  'always': 3269,
#  'bubble': 21,
#  'bath': 142,
#  'wash': 1265,
#  'must': 1365,
#  'bubbles': 24,
#  'arent': 165,
#  'top': 749,
#  'fabulous': 174,
#  'happy': 1373,
#  'month': 436,
#  'old': 1962,
#  'fragnanaces': 1,
#  'hence': 11,
#  'another': 1086,
#  'lots': 609,
#  'fun': 1558,
#  'addition': 270,
#  'take': 942,
#  'amazing': 2436,
#  'baths': 11,
#  'bubblebath': 1,
#  'sensitive': 653,
#  'option': 123,
#  'enjoy': 1292,
#  'break': 318,
#  'small': 943,
#  'size': 884,
#  'months': 486,
#  'smell': 4195,
#  'wonderful': 1422,
#  'recently': 387,
#  'new': 2430,
#  'bottle': 1120,
#  'think': 2098,
#  'may': 521,
#  'shower': 386,
#  'buy': 3354,
#  'pleasant': 383,
#  'whole': 1494,
#  'babies': 125,
#  'mom': 453,
#  'tear': 67,
#  'son': 856,
#  'looks': 1466,
#  'forward': 312,
#  'in1': 4,
#  'convenient': 1379,
#  'liked': 1385,
#  'keeps': 806,
#  'moisturizer': 3136,
#  'soft': 3298,
#  'feels': 1803,
#  'light': 1532,
#  'weight': 211,
#  'hydrates': 66,
#  'heavy': 740,
#  'instantly': 164,
#  'tried': 2322,
#  'regenerist': 122,
#  'smooths': 49,
#  'week': 1218,
#  'difference': 1131,
#  'productno': 3,
#  'feelingwould': 1,
#  'recommend': 3795,
#  'reasonable': 133,
#  'expensive': 535,
#  'results': 1192,
#  'rally': 2,
#  'made': 2106,
#  'real': 537,
#  'n': 97,
#  'container': 472,
#  'helped': 516,
#  'youthful': 118,
#  'recommended': 494,
#  'friends': 799,
#  'continue': 748,
#  'daily': 876,
#  'smoother': 457,
#  'supple': 100,
#  'absorbs': 293,
#  'residue': 367,
#  'younger': 536,
#  'putting': 248,
#  'washing': 555,
#  'nightly': 27,
#  'ability': 82,
#  'older': 271,
#  'overall': 940,
#  'hydration': 183,
#  'attached': 33,
#  'sun': 236,
#  'water': 902,
#  'along': 558,
#  'cooling': 39,
#  'moisture': 446,
#  'weathered': 7,
#  'creamy': 285,
#  'found': 1466,
#  'ago': 714,
#  'aged': 34,
#  'neck': 302,
#  'collarbone': 1,
#  'moisturized': 530,
#  'helps': 747,
#  'non': 203,
#  'greasy': 1356,
#  'finish': 310,
#  'fine': 1096,
#  'makeup': 609,
#  'lines': 1126,
#  'perhaps': 77,
#  'moisturizers': 313,
#  'ive': 3150,
#  'ever': 1659,
#  'without': 2111,
#  'worked': 794,
#  'pat': 28,
#  'apply': 786,
#  'olay': 2008,
#  'regenerating': 60,
#  'effects': 2040,
#  'tighter': 78,
#  'definitely': 2662,
#  '42': 14,
#  'mistaken': 6,
#  'early': 120,
#  '30s': 36,
#  'turn': 173,
#  'tight': 136,
#  'wrinkle': 52,
#  'clear': 341,
#  'cant': 1641,
#  'trust': 340,
#  'quickly': 815,
#  'applies': 48,
#  'thru': 72,
#  'night': 1347,
#  'luxurious': 87,
#  'strong': 873,
#  'overpowering': 250,
#  'prefer': 306,
#  'unscented': 85,
#  'next': 603,
#  'term': 62,
#  'change': 478,
#  'afford': 49,
#  '5': 924,
#  'stars': 355,
#  'miracle': 78,
#  'year': 1316,
#  'havent': 631,
#  'experienced': 58,
#  'outbreaks': 10,
#  'seen': 867,
#  'visible': 141,
#  'improvement': 236,
#  'appears': 80,
#  'brighter': 308,
#  'finally': 434,
#  'moisturizing': 451,
#  'absorb': 46,
#  'leave': 1205,
#  'suffocating': 3,
#  'nothing': 660,
#  'deep': 460,
#  'necessary': 86,
#  'aging': 429,
#  'looking': 1732,
#  '4': 788,
#  'causes': 28,
#  'breakout': 38,
#  'silky': 481,
#  'chemical': 59,
#  'cosmetic': 22,
#  'hate': 171,
#  'picky': 96,
#  'responsible': 10,
#  'design': 181,
#  'push': 73,
#  'package': 291,
#  'dispense': 26,
#  'center': 40,
#  'directions': 89,
#  'awkward': 22,
#  'yummy': 59,
#  'anymore': 216,
#  'variety': 155,
#  '30': 176,
#  'consider': 160,
#  'life': 974,
#  'routinewherever': 1,
#  'international': 3,
#  'traveler': 1,
#  'cared': 6,
#  'regardless': 26,
#  'away': 953,
#  'fills': 28,
#  'imperfections': 15,
#  'might': 358,
#  'highly': 1243,
#  '55': 37,
#  'started': 802,
#  'sister': 94,
#  'told': 304,
#  'softening': 19,
#  'hurt': 61,
#  'smiled': 3,
#  'alone': 198,
#  'reason': 276,
#  'deliberately': 2,
#  'show': 457,
#  'grump': 1,
#  'many': 1836,
#  'including': 179,
#  'priced': 138,
#  'claiming': 8,
#  'miracles': 15,
#  'sinks': 149,
#  'shine': 386,
#  'ill': 383,
#  'going': 1064,
#  'line': 1168,
#  'truly': 412,
#  'wrinkles': 735,
#  'kind': 447,
#  'fragnense': 1,
#  'pleased': 493,
#  'moisturize': 119,
#  'pressing': 7,
#  'dispenses': 27,
#  'amount': 710,
#  'per': 131,
#  'press': 68,
#  'anyone': 944,
#  'mine': 261,
#  'family': 4075,
#  'budget': 106,
#  'spending': 67,
#  'facial': 705,
#  'big': 1053,
#  'chunk': 1,
#  'grocery': 87,
#  'worth': 1286,
#  'rapidly': 4,
#  'maturing': 6,
#  'getting': 986,
#  'pronounced': 16,
#  'watch': 2581,
#  'sales': 48,
#  'coupons': 42,
#  '52': 15,
#  'hydrate': 48,
#  'saying': 105,
#  'ahhhh': 1,
#  'glad': 756,
#  'thank': 1050,
#  'reduced': 104,
#  'skinit': 4,
#  'smoothly': 205,
#  'toned': 43,
#  'everyone': 984,
#  'problems': 366,
#  'wear': 517,
#  'helping': 128,
#  'prevent': 81,
#  'opinion': 425,
#  'comedones': 1,
#  'dimethicone': 1,
#  'silicone': 32,
#  'based': 152,
#  'polymer': 1,
#  'large': 353,
#  'molecule': 1,
#  'clog': 61,
#  'pores': 429,
#  'therefore': 59,
#  'condition': 191,
#  'worse': 79,
#  'swears': 6,
#  'less': 1145,
#  'advertised': 87,
#  'nicely': 271,
#  'evens': 82,
#  'tone': 726,
#  'doent': 3,
#  'leaave': 1,
#  'feelwill': 1,
#  'beautiful': 457,
#  'thought': 1193,
#  'visibly': 132,
#  'softer': 506,
#  'cannot': 294,
#  'believe': 477,
#  'drastic': 22,
#  'rough': 118,
#  'peeling': 32,
#  'young': 472,
#  'opens': 16,
#  'allows': 124,
#  'breathe': 16,
#  'sort': 83,
#  'comfort': 96,
#  'easily': 766,
#  'immediately': 287,
#  'produc': 2,
#  'stop': 361,
#  'powering': 58,
#  'subtle': 127,
#  '16': 39,
#  '66': 4,
#  'anything': 971,
#  'sending': 36,
#  'updates': 10,
#  'wonders': 200,
#  'nourishing': 29,
#  'quality': 1320,
#  'intensive': 22,
#  'moisturizes': 144,
#  'wrinklescrows': 1,
#  'soaks': 70,
#  'aroma': 49,
#  'therapy': 51,
#  'took': 573,
#  'longer': 782,
#  'hoped': 46,
#  'realize': 52,
#  'regiment': 21,
#  'samemy': 1,
#  'learned': 73,
#  'changed': 209,
#  'formula': 266,
#  'probably': 349,
#  'judge': 14,
#  'certain': 97,
#  'white': 512,
#  'black': 305,
#  'unappealing': 3,
#  'surface': 251,
#  'represent': 3,
#  'sensational': 4,
#  'vsop': 1,
#  'nature': 40,
#  'point': 242,
#  'skinn': 1,
#  'cleansing': 56,
#  'morning': 699,
#  'literally': 125,
#  'micro': 15,
#  'dermabrasion': 1,
#  'treatment': 184,
#  'land': 8,
#  'peel': 34,
#  'activating': 2,
#  'serum': 371,
#  'eye': 243,
#  '62': 8,
#  '10': 475,
#  'shallow': 3,
#  'softermy': 1,
#  'noticeable': 260,
#  'although': 428,
#  '40': 139,
#  '50': 94,
#  'contour': 3,
#  'hides': 8,
#  'blemishes': 47,
#  'people': 887,
#  'rinklles': 1,
#  'greases': 1,
#  'gives': 480,
#  'glow': 259,
#  'saw': 905,
#  'brought': 229,
#  'friend': 331,
#  'moor': 1,
#  'firm': 105,
#  'thats': 575,
#  'sooooooooo': 1,
#  'cool': 318,
#  'heal': 14,
#  'damaged': 108,
#  'dark': 535,
#  'circles': 103,
#  'around': 1713,
#  'eyes': 643,
#  'impressed': 530,
#  'mask': 764,
#  'cpap': 11,
#  'machine': 355,
#  'caused': 55,
#  'area': 433,
#  'nose': 150,
#  'cheeks': 86,
#  'flaky': 93,
#  'raw': 58,
#  'areas': 321,
#  'irritated': 42,
#  'red': 338,
#  'moist': 135,
#  'wanted': 621,
#  'thanks': 1004,
#  'making': 755,
#  'helpful': 123,
#  'useful': 117,
#  'likely': 84,
#  'ego': 4,
#  'appearance': 302,
#  'chin': 30,
#  'typically': 90,
#  'numerous': 63,
#  'seem': 425,
#  'noticing': 63,
#  'plus': 805,
#  'taking': 161,
#  'extra': 570,
#  'care': 573,
#  'cleansed': 14,
#  'hooked': 137,
#  'itching': 48,
#  'needs': 417,
#  'something': 932,
#  'aspect': 58,
#  'everything': 1717,
#  'false': 17,
#  'advertising': 7,
#  'moiste': 1,
#  'glowing': 92,
#  'ten': 78,
#  'rubbing': 34,
#  'wifes': 18,
#  'fantastic': 713,
#  'originally': 59,
#  'lobe': 2,
#  'person': 185,
#  'struggleing': 1,
#  'yrs': 72,
#  'blotches': 21,
#  'smelling': 1026,
#  'stuff': 792,
#  'cuz': 22,
#  'wrinkly': 3,
#  '31': 9,
#  'high': 554,
#  'end': 754,
#  'designer': 5,
#  'cosmetics': 18,
#  'rock': 72,
#  'solid': 146,
#  'claims': 159,
#  'regularly': 103,
#  'waste': 138,
#  'within': 287,
#  'slightly': 141,
#  'relaxing': 26,
#  'revitalizes': 2,
#  'youth': 38,
#  'inside': 169,
#  'silly': 59,
#  'household': 254,
#  'else': 597,
#  'isnt': 567,
#  'brand': 1141,
#  'got': 2131,
#  'factory': 8,
#  'reaction': 78,
#  'rather': 209,
#  'applied': 319,
#  'directed': 60,
#  'positive': 85,
#  'wasnt': 718,
#  'women': 112,
#  'sharing': 23,
#  'beauty': 137,
#  'tip': 94,
#  'confident': 131,
#  'nd': 11,
#  'crack': 30,
#  'constantly': 175,
#  'comment': 82,
#  'lovely': 163,
#  'commenting': 10,
#  'actual': 86,
#  'age': 684,
#  'huge': 401,
#  'staying': 76,
#  'velvety': 22,
#  'rich': 221,
#  'drinks': 26,
#  'hydrating': 112,
#  'dewy': 38,
#  'nongreasy': 95,
#  'puts': 66,
#  'palm': 14,
#  'contaminating': 3,
#  'unused': 6,
#  'touching': 71,
#  'fingers': 127,
#  'full': 704,
#  'covering': 24,
#  'hesitate': 31,
#  'absorbes': 7,
#  'wonderfully': 156,
#  'turned': 182,
#  '60': 41,
#  'insist': 5,
#  '45': 77,
#  'several': 766,
#  'however': 965,
#  'knew': 238,
#  'core': 15,
#  'amazed': 177,
#  'tell': 550,
#  'excited': 473,
#  'consistency': 183,
#  'rub': 116,
#  'pillow': 33,
#  'switch': 152,
#  'improved': 182,
#  'skins': 70,
#  'texture': 593,
#  'softand': 4,
#  'smoothand': 1,
#  'yet': 790,
#  'effective': 374,
#  'wearing': 206,
#  'bed': 275,
#  'regenerates': 1,
#  'skinrichruby': 1,
#  'lives': 114,
#  'promise': 50,
#  'deaged': 1,
#  'twenty': 20,
#  'short': 361,
#  'totally': 391,
#  'worrying': 34,
#  'either': 374,
#  'starry': 1,
#  'messy': 300,
#  'dayfor': 1,
#  'choose': 104,
#  'nearly': 123,
#  'discontinued': 149,
#  'settled': 10,
#  'inexpensive': 82,
#  'contained': 29,
#  'wakeup': 1,
#  'healthy': 503,
#  'offers': 54,
#  'available': 340,
#  'earlier': 61,
#  'cost': 279,
#  'refreshed': 160,
#  'quite': 678,
#  '18': 54,
#  'renewed': 8,
#  'experimenting': 9,
#  'greatmake': 1,
#  'dryness': 139,
#  'dissappears': 1,
#  'refreshedlove': 1,
#  'commented': 47,
#  'looked': 699,
#  'expected': 391,
#  'companyi': 1,
#  'senior': 19,
#  'seniors': 7,
#  'skinthis': 2,
#  'tho': 39,
#  '88': 3,
#  'guess': 157,
#  'thin': 184,
#  'eary': 1,
#  '70s': 16,
#  'nurses': 4,
#  'prove': 7,
#  'return': 142,
#  'brightness': 113,
#  'tightness': 18,
#  'recognized': 5,
#  'support': 38,
#  'health': 95,
#  'absorbing': 27,
#  'deeply': 26,
#  'sunblock': 36,
#  'protecting': 32,
#  'claimed': 27,
#  'satisfied': 252,
#  'seventies': 1,
#  'home': 1838,
#  'lady': 39,
#  '15': 216,
#  'given': 221,
#  'pore': 24,
#  'scrub': 139,
#  'count': 79,
#  'throughout': 372,
#  'starting': 190,
#  'stuffit': 1,
#  'directly': 45,
#  'incredible': 184,
#  'sencity': 1,
#  'velvet': 12,
#  'licensed': 4,
#  'aesthetician': 1,
#  'medical': 33,
#  'grade': 24,
#  'mother': 303,
#  'outstanding': 115,
#  'forehead': 121,
#  'appear': 108,
#  'wrinkled': 6,
#  'efficient': 91,
#  'similar': 185,
#  'pricey': 90,
#  'name': 253,
#  'olays': 34,
#  'fact': 558,
#  'general': 118,
#  'public': 69,
#  'penetrating': 7,
#  'lasting': 217,
#  'wrong': 328,
#  'issues': 326,
#  'horrible': 74,
#  'restored': 27,
#  'gave': 424,
#  '61': 12,
#  'anywhere': 229,
#  'near': 139,
#  'basis': 181,
#  'healthier': 189,
#  'shines': 34,
#  'aircraft': 3,
#  '0': 12,
#  'humidity': 26,
#  'skini': 8,
#  'samples': 89,
#  'harsh': 134,
#  'irritate': 96,
#  'working': 376,
#  'said': 517,
#  'coming': 255,
#  'hold': 371,
#  'clock': 9,
#  'adminti': 1,
#  'melts': 19,
#  'computer': 88,
#  'remind': 19,
#  'loss': 26,
#  'problem': 620,
#  '6': 325,
#  'flakey': 18,
#  'serious': 79,
#  'smoothing': 58,
#  'effect': 202,
#  'regerest': 1,
#  'apperence': 2,
#  'whether': 132,
#  'creamin': 1,
#  'awake': 17,
#  'rengenerating': 1,
#  'reduce': 118,
#  'lightweight': 262,
#  'pliant': 1,
#  'nobody': 14,
#  'believes': 7,
#  '57': 19,
#  'moisturizerfeels': 1,
#  'job': 1704,
#  '74': 5,
#  'stronger': 102,
#  'hopeless': 2,
#  'loveit': 2,
#  'theres': 242,
#  'giving': 192,
#  'reminds': 79,
#  'touch': 403,
#  'horses': 7,
#  'child': 210,
#  'postmenopausal': 1,
#  'drier': 42,
#  'different': 1160,
#  '13': 52,
#  'wait': 710,
#  'tomorrow': 22,
#  'rosacea': 17,
#  'thickness': 52,
#  'bedtime': 46,
#  'wake': 118,
#  'kissed': 4,
#  'drink': 67,
#  '81': 1,
#  ...}

# %% [markdown]
# ##### Negativas

# %%
neg
# Out:
# {'read': 108,
#  'reviews': 234,
#  'looking': 235,
#  'buying': 196,
#  'one': 1575,
#  'couples': 1,
#  'lubricants': 1,
#  'ultimately': 7,
#  'disappointed': 656,
#  'didnt': 606,
#  'even': 569,
#  'live': 54,
#  'starters': 3,
#  'neither': 17,
#  'boyfriend': 5,
#  'could': 456,
#  'notice': 118,
#  'sort': 22,
#  'enhanced': 5,
#  'captivating': 2,
#  'sensation': 14,
#  'however': 340,
#  'messy': 16,
#  'consistency': 53,
#  'reminiscent': 1,
#  'liquidy': 4,
#  'vaseline': 10,
#  'difficult': 55,
#  'clean': 286,
#  'pleasant': 45,
#  'especially': 64,
#  'since': 326,
#  'lacked': 3,
#  'expecting': 43,
#  'im': 707,
#  'paid': 27,
#  'much': 521,
#  'lube': 3,
#  'wont': 241,
#  'use': 1404,
#  'normal': 69,
#  'personal': 8,
#  'lubricant': 3,
#  '1': 181,
#  'less': 154,
#  'money': 403,
#  '2': 401,
#  'mess': 119,
#  'husband': 111,
#  'bought': 916,
#  'gel': 798,
#  'us': 69,
#  'caused': 56,
#  'irritation': 13,
#  'felt': 194,
#  'like': 1489,
#  'burning': 25,
#  'skin': 808,
#  'wouldnt': 122,
#  'recommend': 298,
#  'spice': 3,
#  'things': 76,
#  'bedroom': 5,
#  'highly': 38,
#  'product': 2859,
#  'absolutely': 106,
#  'love': 502,
#  'ky': 6,
#  'mine': 49,
#  'thought': 363,
#  'would': 1361,
#  'similar': 35,
#  'affect': 4,
#  'nothing': 237,
#  'buy': 565,
#  'earlier': 10,
#  'today': 80,
#  'excited': 171,
#  'check': 26,
#  'based': 35,
#  'description': 20,
#  'something': 317,
#  'regular': 115,
#  'fans': 9,
#  'expected': 92,
#  'left': 281,
#  'little': 260,
#  'try': 457,
#  'impressed': 44,
#  'tingling': 1,
#  'warming': 4,
#  'sticky': 89,
#  'used': 1381,
#  'products': 494,
#  'past': 103,
#  'loved': 388,
#  'disappointing': 99,
#  'extra': 153,
#  'fun': 19,
#  'werevboth': 1,
#  'extremely': 130,
#  'price': 109,
#  'waste': 221,
#  'got': 368,
#  'surprise': 11,
#  'special': 48,
#  'save': 53,
#  'get': 763,
#  'plain': 18,
#  'need': 199,
#  'wish': 159,
#  'return': 135,
#  'refund': 47,
#  'tried': 529,
#  'different': 329,
#  'effect': 33,
#  'change': 359,
#  'first': 819,
#  'te': 1,
#  'using': 1063,
#  'sure': 213,
#  'want': 250,
#  'others': 126,
#  'purchased': 360,
#  'thinking': 82,
#  'original': 488,
#  'dont': 791,
#  'enhance': 6,
#  'time': 766,
#  'bit': 119,
#  'abslutely': 1,
#  'almost': 152,
#  '20': 113,
#  'really': 659,
#  'liking': 9,
#  'n': 11,
#  'variety': 5,
#  'purchase': 227,
#  'type': 73,
#  'maybe': 190,
#  'think': 289,
#  'feeling': 117,
#  'trying': 158,
#  'wife': 36,
#  'enjoy': 41,
#  'feel': 334,
#  'anything': 150,
#  'enhancement': 1,
#  'hisher': 1,
#  'fianc': 1,
#  'passion': 1,
#  'honest': 31,
#  'anyone': 107,
#  '8': 43,
#  'month': 194,
#  'old': 1039,
#  'baby': 93,
#  'irritated': 20,
#  'week': 168,
#  'back': 1073,
#  'receive': 14,
#  'bottle': 680,
#  'ordered': 42,
#  'said': 128,
#  'pack': 35,
#  '6': 110,
#  'review': 668,
#  'collected': 526,
#  'part': 649,
#  'promotion': 526,
#  'cream': 127,
#  'face': 328,
#  'throat': 5,
#  'area': 58,
#  'gone': 96,
#  'generic': 7,
#  'brand': 257,
#  'works': 211,
#  'better': 387,
#  'expensive': 118,
#  'several': 198,
#  'years': 809,
#  'changed': 358,
#  'moisturize': 17,
#  'soft': 88,
#  'sits': 6,
#  'top': 125,
#  'never': 399,
#  'absorbed': 18,
#  'leaves': 144,
#  'slimy': 7,
#  'film': 94,
#  'longer': 265,
#  'oil': 70,
#  'olay': 224,
#  'worked': 331,
#  'well': 524,
#  'new': 1524,
#  'formula': 1265,
#  'horrible': 236,
#  'cannot': 126,
#  'find': 422,
#  'work': 560,
#  'smell': 679,
#  'flowery': 4,
#  'thick': 127,
#  'light': 111,
#  'great': 750,
#  'results': 117,
#  'feels': 102,
#  'greasy': 174,
#  'smells': 221,
#  'awful': 184,
#  'looks': 132,
#  'toned': 4,
#  'wrinkle': 9,
#  'free': 150,
#  'anymore': 119,
#  'five': 32,
#  'star': 62,
#  'many': 354,
#  'yearswhy': 1,
#  'please': 547,
#  'bring': 413,
#  'ive': 495,
#  'terrific': 4,
#  'improved': 81,
#  'terrible': 217,
#  'doesnt': 451,
#  'hydrating': 16,
#  'power': 51,
#  'thinner': 28,
#  'stickier': 3,
#  'heaven': 4,
#  'help': 148,
#  'lips': 34,
#  'tastes': 10,
#  'dump': 4,
#  'shopping': 19,
#  'moisturizer': 274,
#  'alas': 9,
#  'took': 124,
#  'long': 292,
#  'strong': 185,
#  'applied': 88,
#  'unfortunately': 185,
#  'purchasing': 78,
#  'search': 34,
#  'another': 371,
#  'swear': 13,
#  'daily': 70,
#  'creamy': 13,
#  'job': 78,
#  'without': 171,
#  'heavy': 114,
#  'container': 131,
#  'go': 318,
#  'away': 225,
#  'makes': 182,
#  'impossible': 42,
#  'apply': 92,
#  'makeup': 63,
#  '10': 142,
#  'minutes': 119,
#  'touch': 27,
#  'slippery': 2,
#  'scent': 583,
#  'way': 370,
#  'stronger': 35,
#  'give': 198,
#  'ill': 113,
#  'else': 136,
#  'overly': 9,
#  'dry': 380,
#  'havent': 63,
#  'found': 288,
#  'hoping': 88,
#  'able': 167,
#  'affrid': 1,
#  'gets': 87,
#  'bad': 391,
#  'dig': 2,
#  'legs': 18,
#  'days': 256,
#  'row': 2,
#  'wearing': 35,
#  'mask': 37,
#  'unnatural': 1,
#  'coated': 4,
#  'instead': 98,
#  'hydrated': 12,
#  'regenerist': 4,
#  'cvs': 1,
#  'rite': 4,
#  'aid': 4,
#  'around': 136,
#  'wal': 2,
#  'marts': 2,
#  'online': 50,
#  'store': 198,
#  'received': 161,
#  'slightly': 25,
#  'lotion': 90,
#  'cheaper': 36,
#  'order': 55,
#  'walmart': 37,
#  'mother': 35,
#  'vowed': 3,
#  'started': 254,
#  'paying': 14,
#  'attention': 11,
#  'skincare': 7,
#  'gave': 111,
#  'ever': 221,
#  'needed': 71,
#  'thing': 239,
#  'spent': 35,
#  'exploring': 1,
#  'highend': 5,
#  'brands': 80,
#  'understand': 55,
#  'upset': 73,
#  'tampered': 3,
#  'appears': 21,
#  'theyve': 11,
#  'watered': 15,
#  'mushy': 1,
#  'point': 44,
#  'day': 421,
#  'starts': 26,
#  'peeling': 19,
#  'mom': 27,
#  'forced': 31,
#  'look': 262,
#  'whole': 109,
#  'line': 133,
#  'weve': 20,
#  'stayed': 15,
#  'lives': 5,
#  'sad': 109,
#  'probably': 75,
#  'leave': 102,
#  'faces': 9,
#  'nourished': 3,
#  'full': 90,
#  'crumbles': 1,
#  'soon': 91,
#  'brushed': 2,
#  'night': 90,
#  'moisture': 44,
#  'nutragena': 3,
#  'greatgreatmefeels': 1,
#  'succulent': 1,
#  'silky': 18,
#  'smooth': 69,
#  'enriching': 1,
#  'windows': 33,
#  'streaks': 60,
#  'although': 63,
#  'seem': 89,
#  'ok': 104,
#  'surfaces': 7,
#  'windsheild': 1,
#  'washer': 149,
#  'fluid': 16,
#  'spray': 700,
#  'windex': 72,
#  'kinds': 6,
#  'matter': 64,
#  'times': 315,
#  'wash': 289,
#  '5050': 2,
#  'mixture': 2,
#  'white': 151,
#  'vinegar': 33,
#  'water': 340,
#  'good': 770,
#  'ago': 259,
#  'reformulated': 11,
#  'noticed': 220,
#  'last': 351,
#  'year': 187,
#  'result': 23,
#  '23': 23,
#  'still': 359,
#  'streaky': 7,
#  'seen': 72,
#  'whats': 22,
#  'going': 224,
#  'resorted': 8,
#  'soap': 71,
#  'lemon': 11,
#  'rinse': 36,
#  'sparkle': 2,
#  'lost': 91,
#  'loyal': 64,
#  'customer': 114,
#  'alone': 37,
#  'though': 146,
#  'spend': 45,
#  'lemons': 2,
#  'despite': 16,
#  'reputation': 5,
#  'glass': 47,
#  'cleaner': 129,
#  'done': 99,
#  'often': 38,
#  'smudges': 9,
#  'appear': 18,
#  'mirrors': 21,
#  'within': 120,
#  'hours': 105,
#  'cleaning': 231,
#  'paper': 44,
#  'towel': 21,
#  'newspaper': 5,
#  'lintfree': 1,
#  'cloth': 18,
#  'windexs': 1,
#  'streakfree': 5,
#  'shine': 30,
#  'false': 6,
#  'advertisement': 2,
#  'ask': 22,
#  'choice': 31,
#  'family': 82,
#  'introduced': 7,
#  'always': 283,
#  'unhappy': 46,
#  'filmstreaks': 2,
#  'cant': 327,
#  'rid': 31,
#  'towels': 75,
#  'testing': 61,
#  'car': 14,
#  'windshield': 4,
#  'oily': 152,
#  'also': 462,
#  'bathroom': 25,
#  'mirror': 11,
#  'guess': 103,
#  'basics': 3,
#  'forty': 2,
#  'problem': 298,
#  'yet': 82,
#  'failed': 42,
#  'switched': 55,
#  'amazing': 76,
#  'environment': 8,
#  'couple': 175,
#  'window': 18,
#  'three': 145,
#  'everywhere': 40,
#  'sun': 41,
#  'shines': 2,
#  '30': 54,
#  'doubt': 8,
#  'cut': 42,
#  'costs': 13,
#  'increase': 5,
#  'profits': 3,
#  'definitely': 114,
#  'repeat': 9,
#  'seems': 149,
#  'worse': 106,
#  'finally': 103,
#  'frustrating': 38,
#  'loss': 12,
#  'taken': 26,
#  'standard': 7,
#  'ruined': 181,
#  'changing': 24,
#  '50': 16,
#  'topped': 1,
#  'tables': 3,
#  'everyone': 70,
#  'available': 49,
#  'plus': 51,
#  'favorite': 92,
#  'cleaners': 17,
#  'smeary': 2,
#  'residue': 85,
#  'unprint': 1,
#  'packing': 8,
#  'types': 31,
#  'cloths': 25,
#  'happening': 11,
#  'happened': 121,
#  'squeegee': 1,
#  'microfiber': 18,
#  'newsprint': 1,
#  'two': 363,
#  'gross': 24,
#  'fact': 77,
#  'every': 272,
#  'washed': 146,
#  '4': 147,
#  'lint': 5,
#  'ended': 57,
#  'ammonia': 5,
#  'fifth': 5,
#  'complete': 40,
#  'streaked': 4,
#  'useless': 76,
#  'johnson': 3,
#  'company': 74,
#  'produced': 7,
#  'dog': 14,
#  'licking': 2,
#  'biggest': 15,
#  'mistake': 49,
#  'cleaned': 35,
#  'sprayed': 31,
#  'streak': 14,
#  'rewash': 64,
#  'dirty': 42,
#  'ran': 37,
#  'life': 72,
#  'adequate': 6,
#  'lately': 12,
#  'covered': 19,
#  'haze': 2,
#  'blotches': 9,
#  'best': 202,
#  'whatever': 27,
#  'made': 390,
#  'table': 18,
#  'tops': 18,
#  'windexmultisurface': 2,
#  'went': 227,
#  'packaging': 128,
#  'quality': 234,
#  'smudged': 3,
#  'usual': 31,
#  'usually': 97,
#  'particular': 23,
#  'enjoyed': 29,
#  'passed': 6,
#  'knew': 19,
#  'producing': 5,
#  'consumer': 39,
#  'ways': 12,
#  'keep': 171,
#  'cost': 53,
#  'effective': 40,
#  'consumersbut': 1,
#  'maintain': 8,
#  'happy': 196,
#  'dull': 27,
#  'finish': 41,
#  'froze': 2,
#  'shipment': 2,
#  'repurchased': 4,
#  'tell': 84,
#  'wrong': 87,
#  'operator': 1,
#  'complaining': 8,
#  'low': 48,
#  'rating': 26,
#  'know': 286,
#  'whether': 15,
#  'ingredients': 112,
#  'costly': 9,
#  'remember': 36,
#  'wipe': 18,
#  '15': 67,
#  'careful': 21,
#  'driving': 7,
#  'tonight': 13,
#  'streaking': 3,
#  'causes': 10,
#  'glare': 2,
#  'tomorrow': 9,
#  '25': 23,
#  'commercials': 7,
#  'state': 17,
#  'forget': 8,
#  'make': 351,
#  'kitchen': 37,
#  'see': 337,
#  'hazy': 1,
#  'forth': 6,
#  'cotton': 10,
#  'dish': 11,
#  'rag': 7,
#  'smears': 2,
#  'undersides': 1,
#  'nearby': 2,
#  'seemed': 67,
#  'fine': 200,
#  'wonder': 22,
#  'previous': 86,
#  'residual': 4,
#  'muscle': 1,
#  'reclean': 1,
#  'bottom': 65,
#  'requiredyou': 1,
#  'put': 315,
#  'label': 38,
#  '3': 296,
#  'near': 48,
#  'working': 310,
#  'successfully': 7,
#  'disappointment': 82,
#  'home': 116,
#  'remedies': 4,
#  '100': 17,
#  'approach': 2,
#  'current': 20,
#  'gallon': 2,
#  'refill': 30,
#  'reselling': 1,
#  'inn': 1,
#  'months': 422,
#  'translucent': 7,
#  'hasnt': 17,
#  'personally': 19,
#  'bottles': 109,
#  'lousy': 12,
#  'heat': 29,
#  'propane': 1,
#  'winter': 26,
#  'may': 112,
#  'come': 217,
#  'easily': 69,
#  'interior': 2,
#  'wifes': 2,
#  'twice': 81,
#  'upon': 34,
#  'recent': 22,
#  'experience': 43,
#  'cars': 5,
#  'poor': 122,
#  'goto': 11,
#  'care': 138,
#  'consistently': 6,
#  '40': 20,
#  'provide': 28,
#  'performance': 30,
#  'came': 189,
#  'expect': 48,
#  'rely': 3,
#  'serves': 1,
#  'frustration': 10,
#  'produce': 12,
#  'grease': 18,
#  'cutting': 3,
#  'ability': 26,
#  'provides': 11,
#  'endless': 3,
#  'seeking': 2,
#  'alternatives': 2,
#  'oz': 14,
#  'orignial': 2,
#  'weeks': 240,
#  'trigger': 309,
#  'broke': 413,
#  'uses': 119,
#  '80': 11,
#  'second': 267,
#  'intentions': 4,
#  'switching': 28,
#  'rest': 41,
#  'mirrow': 2,
#  'stuck': 150,
#  'completely': 170,
#  'decades': 24,
#  'either': 97,
#  'called': 35,
#  'dripless': 1,
#  'ammoniad': 1,
#  'disheartening': 2,
#  'coffe': 1,
#  'dining': 5,
#  'wiping': 5,
#  'carefully': 10,
#  'removing': 22,
#  'beads': 1,
#  'making': 90,
#  'quite': 90,
#  'task': 5,
#  'question': 11,
#  'truly': 26,
#  'otherwise': 33,
#  'getting': 136,
#  'wondering': 13,
#  'kept': 74,
#  'multiple': 34,
#  'everything': 118,
#  'lift': 33,
#  'checked': 23,
#  'putting': 71,
#  'comes': 79,
#  'shows': 14,
#  'rather': 70,
#  'dirt': 26,
#  'recently': 133,
#  'leaving': 52,
#  'kind': 73,
#  'conclude': 1,
#  'note': 16,
#  'reporting': 1,
#  '35': 6,
#  'changes': 49,
#  'severely': 8,
#  'offerings': 2,
#  'including': 31,
#  'newer': 27,
#  'versions': 7,
#  'solution': 197,
#  'significantly': 4,
#  'maximize': 1,
#  'hour': 44,
#  'theres': 26,
#  'swipe': 2,
#  'inside': 52,
#  'outside': 40,
#  'filmy': 4,
#  'annoying': 24,
#  'thru': 19,
#  'drive': 7,
#  '67': 4,
#  'cloudy': 9,
#  'woman': 17,
#  'issues': 81,
#  'issue': 105,
#  'continue': 77,
#  'say': 244,
#  'goodbye': 5,
#  'thank': 48,
#  'list': 25,
#  'must': 96,
#  'actually': 130,
#  'quick': 26,
#  'run': 58,
#  'friend': 49,
#  'text': 1,
#  'stopping': 5,
#  'isnt': 89,
#  'restored': 3,
#  'discontinue': 24,
#  'cause': 44,
#  'satisfied': 29,
#  'performed': 5,
#  'miracles': 3,
#  'smudge': 2,
#  'porsche': 1,
#  'creates': 16,
#  'surface': 18,
#  'micro': 4,
#  'fiber': 1,
#  'aptly': 1,
#  'named': 4,
#  'failure': 10,
#  'minimised': 1,
#  'immediately': 69,
#  'cot': 1,
#  'currently': 18,
#  'searching': 36,
#  'lots': 32,
#  'people': 152,
#  'posed': 2,
#  'answer': 14,
#  'forthcoming': 1,
#  'suggest': 29,
#  'listen': 24,
#  'customers': 55,
#  'pdq': 1,
#  'worst': 124,
#  'sprayer': 246,
#  'squeezes': 1,
#  'flimsy': 11,
#  'squeezer': 1,
#  'snaps': 8,
#  'rendering': 7,
#  'forever': 48,
#  'bulk': 4,
#  'refills': 13,
#  'idea': 201,
#  'guy': 15,
#  'hired': 1,
#  'hem': 1,
#  'break': 119,
#  'easier': 41,
#  'oris': 1,
#  'shoddy': 4,
#  'design': 113,
#  'noname': 1,
#  'empty': 19,
#  'overs': 1,
#  'name': 49,
#  'cares': 4,
#  'cleans': 24,
#  'breaks': 49,
#  'instantly': 10,
#  'marketing': 7,
#  'bonus': 3,
#  'pat': 2,
#  'saving': 15,
#  'cents': 3,
#  'inferior': 11,
#  'nozzle': 38,
#  'faithful': 15,
#  'user': 72,
#  'sparkling': 2,
#  'faint': 9,
#  'blue': 167,
#  'tells': 4,
#  'leads': 8,
#  'remodeled': 1,
#  'hot': 93,
#  'stuff': 144,
#  'happen': 39,
#  'scummy': 2,
#  'bee': 3,
#  'wiped': 4,
#  'agree': 37,
#  'mel': 1,
#  'curious': 7,
#  'sc': 1,
#  'heather': 1,
#  'refers': 1,
#  'heck': 7,
#  'self': 14,
#  'keeps': 49,
#  'breaking': 63,
#  'broken': 120,
#  'red': 95,
#  'plastic': 191,
#  'triggers': 9,
#  '30years': 1,
#  'purchases': 8,
#  'downsomething': 1,
#  'discount': 1,
#  'far': 101,
#  'betterwhat': 1,
#  'code': 5,
#  '19800702984': 1,
#  'cap': 40,
#  'tdo': 1,
#  'mode': 4,
#  'indicators': 1,
#  'across': 17,
#  'timeplease': 2,
#  'believe': 82,
#  'carried': 8,
#  'seams': 7,
#  'knows': 16,
#  'guys': 21,
#  'messed': 9,
#  'perfection': 5,
#  'stop': 93,
#  'messing': 2,
#  'already': 88,
#  'sold': 25,
#  'packages': 9,
#  'california': 4,
#  'regulations': 1,
#  'prohibiting': 1,
#  'given': 55,
#  'excellent': 25,
#  'growing': 9,
#  'parents': 3,
#  'cloudiness': 1,
#  'ammoniafree': 1,
#  'house': 77,
#  'open': 82,
#  'perfect': 65,
#  'sticks': 18,
#  'position': 9,
#  'takes': 55,
#  'hate': 98,
#  'somewhat': 19,
#  'front': 89,
#  'turn': 45,
#  'shouldnt': 23,
#  'picky': 5,
#  '5': 128,
#  'foot': 3,
#  'throughout': 22,
#  'prided': 1,
#  'cleanliness': 3,
#  'ingredient': 11,
#  'creating': 9,
#  'consider': 39,
#  'bottling': 1,
#  'hard': 188,
#  'drain': 8,
#  'correct': 15,
#  'suggested': 8,
#  'primarily': 2,
#  'exactly': 46,
#  'improvement': 22,
#  'crazy': 28,
#  'appliances': 2,
#  'disappointingly': 1,
#  'start': 62,
#  'various': 11,
#  'sense': 22,
#  'research': 28,
#  'take': 168,
#  'sprayswipe': 1,
#  'buyer': 10,
#  'beware': 23,
#  'taste': 92,
#  '55': 4,
#  'close': 62,
#  'bar': 16,
#  'aficionado': 1,
#  'widely': 1,
#  'isi': 2,
#  'flavor': 25,
#  'fulfillment': 1,
#  'thin': 77,
#  'bars': 6,
#  'flat': 34,
#  'square': 11,
#  'bland': 8,
#  'dark': 88,
#  'chocolate': 15,
#  'adds': 3,
#  'trick': 11,
#  'keeping': 16,
#  'hunger': 1,
#  'bay': 4,
#  'hair': 1288,
#  'shampoo': 296,
#  'dirtier': 2,
#  'washing': 137,
#  'enough': 153,
#  'later': 65,
#  'smelled': 97,
#  'volume': 30,
#  'sudden': 12,
#  'removed': 21,
#  '2in1': 3,
#  'conditioner': 213,
#  'wasnt': 182,
#  'nearly': 42,
#  'offer': 30,
#  'compares': 4,
#  'youd': 12,
#  'man': 12,
#  'market': 85,
#  'lose': 29,
#  'powering': 7,
#  'feminine': 4,
#  'aussome': 1,
#  'except': 30,
#  'real': 58,
#  'scalp': 111,
#  'problems': 92,
#  'sores': 6,
#  'falling': 21,
#  'drying': 41,
#  'thicker': 16,
#  'nice': 193,
#  'hardly': 18,
#  'let': 95,
#  'appreciate': 15,
#  'aussie': 3,
#  'opposite': 10,
#  'became': 51,
#  'limp': 5,
#  'mention': 25,
#  'grimy': 1,
#  'diappointed': 1,
#  'sorry': 89,
#  'dried': 79,
#  'says': 71,
#  'ginger': 7,
#  'jojoba': 1,
#  'cherries': 1,
#  'world': 18,
#  'miss': 33,
#  'mild': 25,
#  'rude': 3,
#  'burns': 17,
#  'eyes': 167,
#  'avoid': 28,
#  'pay': 37,
#  'sample': 92,
#  'influenster': 42,
#  'fresh': 77,
#  'fruity': 1,
#  'rinsing': 11,
#  'slip': 4,
#  'pure': 16,
#  'straw': 14,
#  'scream': 3,
#  'rashes': 5,
#  'neck': 49,
#  'itch': 17,
#  'nonstop': 2,
#  'cheeks': 17,
#  'bumpy': 5,
#  'barely': 38,
#  'noticeable': 18,
#  'overpriced': 9,
#  'boys': 12,
#  ...}

# %% [markdown]
# ### Teniendo en cuenta la cantidad de palabras positivas y negativas del review determine quétan positivo, negativo o neutral es el mismo para el producto.

# %%
# add sentiment anaylsis columns
sid = SentimentIntensityAnalyzer()
datos['reviewsPol.text'] = datos['reviews.text'].apply(lambda x: sid.polarity_scores(x))
datos = pd.concat([datos.drop(['reviewsPol.text'], axis=1), datos['reviewsPol.text'].apply(pd.Series)], axis=1)
datos.head()
# Out:
#                      id            brand  \
# 0  AV13O1A8GV-KLJ3akUyj  Universal Music
# 1  AV14LG0R-jtxr-f38QfS         Lundberg
# 2  AV14LG0R-jtxr-f38QfS         Lundberg
# 3  AV16khLE-jtxr-f38VFn              K-Y
# 4  AV16khLE-jtxr-f38VFn              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z  6.02537E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 3  kylovesensualitypleasuregel/b00u2whx8s,0679819...
# 4  kylovesensualitypleasuregel/b00u2whx8s,0679819...
#
#                          manufacturer manufacturerNumber  \
# 0  Universal Music Group / Cash Money           14331328
# 1                            Lundberg             574764
# 2                            Lundberg             574764
# 3                                 K-Y        67981934427
# 4                                 K-Y        67981934427
#
#                                          name  ... reviews.userCity  \
# 0   Pink Friday: Roman Reloaded Re-Up (w/dvd)  ...      Los Angeles
# 1  Lundberg Organic Cinnamon Toast Rice Cakes  ...              NaN
# 2  Lundberg Organic Cinnamon Toast Rice Cakes  ...              NaN
# 3            K-Y Love Sensuality Pleasure Gel  ...              NaN
# 4            K-Y Love Sensuality Pleasure Gel  ...              NaN
#
#   reviews.userProvince reviews.username          upc review.class  \
# 0                  NaN           Joshua  6.02537E+11          Pos
# 1                  NaN        Dorothy W  73416000391          Pos
# 2                  NaN        Dorothy W  73416000391          Pos
# 3                  NaN          Rebecca  67981934427          Neg
# 4                  NaN        Walker557  67981934427          Neg
#
#                                   reviewsnostop.text    neg    neu    pos  \
# 0  [love, album, good, hip, hop, side, current, p...  0.094  0.627  0.278
# 1  [good, flavor, review, collected, part, promot...  0.000  0.633  0.367
# 2                                     [good, flavor]  0.000  0.256  0.744
# 3  [read, reviews, looking, buying, one, couples,...  0.196  0.715  0.089
# 4  [husband, bought, gel, us, gel, caused, irrita...  0.286  0.582  0.132
#
#   compound
# 0   0.6908
# 1   0.4404
# 2   0.4404
# 3  -0.7305
# 4  -0.4423
#
# [5 rows x 31 columns]

# %% [markdown]
# Lo que se hizo anteriormente fue usa el analisis de sentimiento para obtener la polaridad del texto y su coeficiente de positivo, negativo y neutral. Para asi obtener un valor compuesto que se encuentre entre -1 y 1. Si es un numero <0 es porque es un review negativo y si es >0 es porque es positivo. Este valor compuesto se encuentra en la columna llamada 'compound', para clasificar los reviews segun este valor se hara una funcion y guardar bajo la columna 'review.classification'.

# %%
def classification(rating):
    if rating < 0:
        return 'Neg'
    elif rating == 0:
        return 'Neutral'
    else:
        return 'Pos'
datos['review.classification'] = datos['compound'].apply(lambda rate: classification(rate))
datos[['reviews.text', 'review.class', 'review.classification']].head()
# Out:
#                                         reviews.text review.class  \
# 0  love album good hip hop side current pop sound...          Pos
# 1        good flavor review collected part promotion          Pos
# 2                                        good flavor          Pos
# 3  read reviews looking buying one couples lubric...          Neg
# 4  husband bought gel us gel caused irritation fe...          Neg
#
#   review.classification
# 0                   Pos
# 1                   Pos
# 2                   Pos
# 3                   Neg
# 4                   Neg

# %% [markdown]
# Como podemos ver compound nos ayudo a conocer, mediante el analisis de texto si el review era positivo o negativo, lo cual concuerda con la categorias dadas por review.class que fue por el rating (de 1 a 5) que se le dio al producto.

# %% [markdown]
# ### Determinación de diferentes productos y/o clientes
# #### Cuáles son los 10 productos de mejor calidad dado su review
# Esto se hace a traves de su valor de pos segun el analisis de sentimientos, ya que se sabe que entre más cercano a 1, mejor fue la calidad del review en la columna de pos

# %%
datos.sort_values(by='pos', ascending = False)[['name','brand','reviews.text', 'review.class', 'review.classification','pos']].head(10)
# Out:
#                                                     name  \
# 35404  Maybelline Eye Studio Color Plush Shadow Quad,...
# 27414            Meguiar's Ultimate Quik Detailer 22-Oz.
# 51204                              Cinnamon Toast Crunch
# 35417  Maybelline Eye Studio Color Plush Shadow Quad,...
# 68467         Nutrigrain Cereal Bars, Mixed Berry, 8 Ct.
# 51214                              Cinnamon Toast Crunch
# 51217                              Cinnamon Toast Crunch
# 68473         Nutrigrain Cereal Bars, Mixed Berry, 8 Ct.
# 35418  Maybelline Eye Studio Color Plush Shadow Quad,...
# 35422  Maybelline Eye Studio Color Plush Shadow Quad,...
#
#                        brand reviews.text review.class review.classification  \
# 35404             Maybelline      awesome          Pos                   Pos
# 27414               Meguiars    excellent          Pos                   Pos
# 51204  Cinnamon Toast Crunch        great          Pos                   Pos
# 35417             Maybelline         good          Pos                   Pos
# 68467            Nutri-Grain        great          Pos                   Pos
# 51214  Cinnamon Toast Crunch         good          Pos                   Pos
# 51217  Cinnamon Toast Crunch        yummy          Pos                   Pos
# 68473            Nutri-Grain     favorite          Pos                   Pos
# 35418             Maybelline        great          Pos                   Pos
# 35422             Maybelline         love          Pos                   Pos
#
#        pos
# 35404  1.0
# 27414  1.0
# 51204  1.0
# 35417  1.0
# 68467  1.0
# 51214  1.0
# 51217  1.0
# 68473  1.0
# 35418  1.0
# 35422  1.0

# %% [markdown]
# #### Cuáles son los 10 productos de menor calidad dado su review
# Esto se hace a traves de su valor de neg segun el analisis de sentimientos, ya que se sabe que entre más cercano a 1, peor fue la calidad del review en la columna de neg

# %%
datos.sort_values(by='neg', ascending = False)[['name','brand','reviews.text', 'review.classification','neg']].head(10)
# Out:
#                                                     name  \
# 6365                    Red (special Edition) (dvdvideo)
# 22182  Chips Ahoy! Original Chocolate Chip - Cookies ...
# 61854           Sanford Glass Beverage Dispenser - Clear
# 36464                  Hawaiian Punch Orange Ocean Juice
# 3497   Nature's Path Flax Plus Maple Pecan Crunch Cereal
# 62856  Independence Day Resurgence (4k/uhd + Blu-Ray ...
# 15837  Lysol Concentrate Deodorizing Cleaner, Origina...
# 65518  Independence Day Resurgence (4k/uhd + Blu-Ray ...
# 26974  Aveeno Baby Continuous Protection Lotion Sunsc...
# 2621   My Big Fat Greek Wedding 2 (blu-Ray + Dvd + Di...
#
#                       brand                       reviews.text  \
# 6365   Summit Entertainment                         disappoint
# 22182            Chips Ahoy                                bad
# 61854      American Atelier                             broken
# 36464        Hawaiian Punch                              gross
# 3497          Nature's Path                                bad
# 62856                   FOX  bad bad bad bad bad bad whywhywhy
# 15837                 Lysol                        kills germs
# 65518                   FOX              bad thought would bad
# 26974                Aveeno                          bad smell
# 2621   Universal Home Video        horrible remake bad writing
#
#       review.classification    neg
# 6365                    Neg  1.000
# 22182                   Neg  1.000
# 61854                   Neg  1.000
# 36464                   Neg  1.000
# 3497                    Neg  1.000
# 62856                   Neg  0.955
# 15837                   Neg  0.778
# 65518                   Neg  0.778
# 26974                   Neg  0.778
# 2621                    Neg  0.778

# %% [markdown]
# **Cuáles son los usuarios que dan la mayor cantidad de reviews a distintos productos.**

# %%
datos['reviews.username'].value_counts()[:15].sort_values(ascending=False)
# Out:
# An anonymous customer    421
# Anonymous                113
# Mike                     105
# Chris                     88
# ByAmazon Customer         58
# Dave                      57
# John                      49
# Rick                      41
# James                     32
# Robert                    31
# Sandy                     30
# Tony                      29
# Lisa                      29
# Steve                     28
# Donna                     24
# Name: reviews.username, dtype: int64

# %% [markdown]
# Tenemos un listado de los 15 usuarios con mas reviews a productos diferentes. Como los usuarios no son únicos, entre los más frecuentes se encuentran usuarios con nombres comunes en los EEUU., o anónimos

# %% [markdown]
# **Cuáles son los usuarios que más reviews negativos y positivos dan en promedio.**

# %%
#Positivos
pos =  datos[datos['review.classification'] == 'Pos'  ]
pos['reviews.username'].value_counts()[:15].sort_values(ascending=False)
# Out:
# An anonymous customer    368
# Mike                     100
# Anonymous                 91
# Chris                     81
# Dave                      54
# John                      44
# ByAmazon Customer         41
# Rick                      34
# James                     29
# Robert                    28
# Sandy                     26
# Tony                      25
# Steve                     24
# Lisa                      23
# Josh                      22
# Name: reviews.username, dtype: int64

# %%
#Negativos

neg =  datos[datos['review.classification'] == 'Neg' ]
neg['reviews.username'].value_counts()[:15].sort_values(ascending=False)
# Out:
# An anonymous customer    34
# ByAmazon Customer        16
# Anonymous                 7
# Lisa                      4
# Rick                      4
# Cool                      4
# Chris                     4
# Mike                      4
# TimmyG84                  3
# Johnny                    3
# Phil                      3
# Mamastress                3
# Lind                      3
# Moochie                   3
# Disappointed              3
# Name: reviews.username, dtype: int64

# %% [markdown]
# **Cuáles son los productores que tienen productos de mejor calidad.**

# %%
mCalidad = datos[datos['neg'] == 0 ]
mCalidad['brand'].value_counts()[:15].sort_values(ascending=False)
# Out:
# Clorox                  8254
# Universal Home Video    5507
# FOX                     3251
# Disney                  3137
# Tide                    2960
# Warner Home Video       2407
# Olay                    1742
# Warner Bros.            1605
# L'Oreal Paris           1567
# Sony Pictures           1408
# L'oreal Paris           1386
# Quilted Northern        1166
# Lionsgate               1043
# Summit Entertainment     664
# Burt's Bees              550
# Name: brand, dtype: int64

# %% [markdown]
# **Cuáles son los productores que tienen productos de peor calidad.**

# %%
pCalidad = datos[datos['neg'] > 0.5 ]
pCalidad['brand'].value_counts()[:15].sort_values(ascending=False)
# Out:
# FOX                           26
# Sony Pictures                 18
# Warner Home Video             17
# Nexxus                         8
# Universal Home Video           8
# Rubbermaid                     8
# Aveeno                         7
# Maybelline                     6
# Clorox                         4
# Warner Bros.                   4
# Tostitos                       4
# Clear Scalp & Hair Therapy     3
# Quilted Northern               3
# Disney                         2
# Lysol                          2
# Name: brand, dtype: int64

# %% [markdown]
# Filtrando las reviews, donde el valor de sentimiento negativo es mayor a 0.5 (donde el máximo es 1.0)
